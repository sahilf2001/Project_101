# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing the Dataset

# %%
data = pd.read_csv('water_dataX.csv',encoding= 'unicode_escape')

# %%
data
# Out:
#      STATION CODE                                          LOCATIONS  \
# 0            1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1            1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2            1475                                ZUARI AT PANCHAWADI
# 3            3181                        RIVER ZUARI AT BORIM BRIDGE
# 4            3182                       RIVER ZUARI AT MARCAIM JETTY
# ...           ...                                                ...
# 1986         1330            TAMBIRAPARANI AT ARUMUGANERI, TAMILNADU
# 1987         1450  PALAR AT VANIYAMBADI WATER SUPPLY HEAD WORK, T...
# 1988         1403                 GUMTI AT U/S SOUTH TRIPURA,TRIPURA
# 1989         1404                GUMTI AT D/S SOUTH TRIPURA, TRIPURA
# 1990         1726   CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA
#
#             STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (µmhos/cm)  \
# 0     DAMAN & DIU  30.6         6.7  7.5                     203
# ...

# %%
data.dtypes # Checking the data type of each column
# Out:
# STATION CODE                        object
# LOCATIONS                           object
# STATE                               object
# Temp                                object
# D.O. (mg/l)                         object
# PH                                  object
# CONDUCTIVITY (µmhos/cm)             object
# B.O.D. (mg/l)                       object
# NITRATENAN N+ NITRITENANN (mg/l)    object
# FECAL COLIFORM (MPN/100ml)          object
# TOTAL COLIFORM (MPN/100ml)Mean      object
# year                                 int64
# dtype: object

# %%
data.isnull().any().sum() # Checking if any null values are present or not
# Out:
# 0

# %% [markdown]
# # Converting required object values to float values{numeric type} for computation

# %%
data['Temp']=pd.to_numeric(data['Temp'],errors='coerce')
data['D.O. (mg/l)']=pd.to_numeric(data['D.O. (mg/l)'],errors='coerce')
data['PH']=pd.to_numeric(data['PH'],errors='coerce')
data['B.O.D. (mg/l)']=pd.to_numeric(data['B.O.D. (mg/l)'],errors='coerce')
data['CONDUCTIVITY (µmhos/cm)']=pd.to_numeric(data['CONDUCTIVITY (µmhos/cm)'],errors='coerce')
data['NITRATENAN N+ NITRITENANN (mg/l)']=pd.to_numeric(data['NITRATENAN N+ NITRITENANN (mg/l)'],errors='coerce')
data['TOTAL COLIFORM (MPN/100ml)Mean']=pd.to_numeric(data['TOTAL COLIFORM (MPN/100ml)Mean'],errors='coerce')

# %%
data.dtypes
# Out:
# STATION CODE                         object
# LOCATIONS                            object
# STATE                                object
# Temp                                float64
# D.O. (mg/l)                         float64
# PH                                  float64
# CONDUCTIVITY (µmhos/cm)             float64
# B.O.D. (mg/l)                       float64
# NITRATENAN N+ NITRITENANN (mg/l)    float64
# FECAL COLIFORM (MPN/100ml)           object
# TOTAL COLIFORM (MPN/100ml)Mean      float64
# year                                  int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# STATION CODE                          0
# LOCATIONS                             0
# STATE                                 0
# Temp                                 92
# D.O. (mg/l)                          31
# PH                                    8
# CONDUCTIVITY (µmhos/cm)              25
# B.O.D. (mg/l)                        43
# NITRATENAN N+ NITRITENANN (mg/l)    225
# FECAL COLIFORM (MPN/100ml)            0
# TOTAL COLIFORM (MPN/100ml)Mean      132
# year                                  0
# dtype: int64

# %%
data.isnull().any()
# Out:
# STATION CODE                        False
# LOCATIONS                           False
# STATE                               False
# Temp                                 True
# D.O. (mg/l)                          True
# PH                                   True
# CONDUCTIVITY (µmhos/cm)              True
# B.O.D. (mg/l)                        True
# NITRATENAN N+ NITRITENANN (mg/l)     True
# FECAL COLIFORM (MPN/100ml)          False
# TOTAL COLIFORM (MPN/100ml)Mean       True
# year                                False
# dtype: bool

# %% [markdown]
# # Removing Null Values with Mean value of respective columns

# %%
data['Temp'].fillna(data['Temp'].mean(),inplace=True)
data['D.O. (mg/l)'].fillna(data['D.O. (mg/l)'].mean(),inplace=True)
data['PH'].fillna(data['PH'].mean(),inplace=True)
data['B.O.D. (mg/l)'].fillna(data['B.O.D. (mg/l)'].mean(),inplace=True)
data['CONDUCTIVITY (µmhos/cm)'].fillna(data['CONDUCTIVITY (µmhos/cm)'].mean(),inplace=True)
data['NITRATENAN N+ NITRITENANN (mg/l)'].fillna(data['NITRATENAN N+ NITRITENANN (mg/l)'].mean(),inplace=True)
data['TOTAL COLIFORM (MPN/100ml)Mean'].fillna(data['TOTAL COLIFORM (MPN/100ml)Mean'].mean(),inplace=True)

# %%
data['STATE'].fillna(data['STATE'].mode(),inplace=True)

# %%
data.isnull().sum()
# Out:
# STATION CODE                        0
# LOCATIONS                           0
# STATE                               0
# Temp                                0
# D.O. (mg/l)                         0
# PH                                  0
# CONDUCTIVITY (µmhos/cm)             0
# B.O.D. (mg/l)                       0
# NITRATENAN N+ NITRITENANN (mg/l)    0
# FECAL COLIFORM (MPN/100ml)          0
# TOTAL COLIFORM (MPN/100ml)Mean      0
# year                                0
# dtype: int64

# %% [markdown]
# # Removing useless data

# %%
data.STATE.tolist()
# Out:
# ['DAMAN & DIU',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'KERALA',
#  'KERALA',
#  'KERALA',
#  'KERALA',
# ...

# %%
statelist = data.STATE.tolist()
for state_index in range(len(statelist)):
    if(len(statelist[state_index].split(","))==2):
        statelist[state_index] = statelist[state_index].split(",")[1]

# %%
statelist # TRIED PROCESSING THE STATE LIST BUT LOT OF NOISE PRESENT IN DATA
# Out:
# ['DAMAN & DIU',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'GOA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'MAHARASHTRA',
#  'KERALA',
#  'KERALA',
#  'KERALA',
#  'KERALA',
# ...

# %%
data.drop('LOCATIONS',axis=1,inplace=True)
data.drop('STATE',axis=1,inplace=True)
data.drop('STATION CODE',axis=1,inplace=True)
#data['STATE'] = pd.Series(statelist)

# %%
data.dtypes
# Out:
# Temp                                float64
# D.O. (mg/l)                         float64
# PH                                  float64
# CONDUCTIVITY (µmhos/cm)             float64
# B.O.D. (mg/l)                       float64
# NITRATENAN N+ NITRITENANN (mg/l)    float64
# FECAL COLIFORM (MPN/100ml)           object
# TOTAL COLIFORM (MPN/100ml)Mean      float64
# year                                  int64
# dtype: object

# %% [markdown]
# # Checking for outliers

# %%
data.describe()
# Out:
#               Temp  D.O. (mg/l)            PH  CONDUCTIVITY (µmhos/cm)  \
# count  1991.000000  1991.000000   1991.000000              1991.000000
# mean     26.209814     6.392637    112.090674              1786.466394
# std       3.287652     1.322515   1875.150167              5517.289887
# min      10.000000     0.000000      0.000000                 0.400000
# 25%      25.000000     5.950000      6.900000                79.000000
# 50%      27.000000     6.700000      7.300000               187.630000
# 75%      28.300000     7.200000      7.700000               620.500000
# max      35.000000    11.400000  67115.000000             65700.000000
#
#        B.O.D. (mg/l)  NITRATENAN N+ NITRITENANN (mg/l)  \
# count    1991.000000                       1991.000000
# mean        6.940049                          1.623079
# std        29.080653                          3.852301
# min         0.100000                          0.000000
# ...

# %%
sns.boxplot(data.Temp)

# %%
sns.boxplot(data['PH'])

# %%
sns.boxplot(data['D.O. (mg/l)'])

# %%
sns.boxplot(data['B.O.D. (mg/l)'])

# %%
sns.boxplot(data['CONDUCTIVITY (µmhos/cm)'])

# %%
sns.boxplot(data['NITRATENAN N+ NITRITENANN (mg/l)'])

# %%
sns.boxplot(data['TOTAL COLIFORM (MPN/100ml)Mean'])

# %%
q1 = data.quantile(0.25)
q3 = data.quantile(0.75)
IQR = q3-q1
IQR
# Out:
# Temp                                   3.300000
# D.O. (mg/l)                            1.250000
# PH                                     0.800000
# CONDUCTIVITY (µmhos/cm)              541.500000
# B.O.D. (mg/l)                          2.700000
# NITRATENAN N+ NITRITENANN (mg/l)       1.343079
# TOTAL COLIFORM (MPN/100ml)Mean      2811.000000
# year                                   5.000000
# dtype: float64

# %%
data_no_outlier = data[~((data<(q1-1.15*IQR))|(data>(q3+1.5*IQR))).any(axis=1)]
data_no_outlier
# Out:
#            Temp  D.O. (mg/l)    PH  CONDUCTIVITY (µmhos/cm)  B.O.D. (mg/l)  \
# 0     30.600000          6.7  7.50                    203.0       6.940049
# 2     29.500000          6.3  6.90                    179.0       1.700000
# 4     29.500000          5.8  7.30                     83.0       1.900000
# 5     30.000000          5.5  7.40                     81.0       1.500000
# 6     29.200000          6.1  6.70                    308.0       1.400000
# ...         ...          ...   ...                      ...            ...
# 1896  26.209814          6.6  7.81                    603.2       2.675000
# 1897  28.000000          6.6  7.49                    571.5       2.091000
# 1898  28.000000          5.4  7.16                     75.8       2.092000
# 1899  30.000000          5.4  7.37                    104.8       1.802000
# 1900  29.000000          5.3  7.37                    102.2       2.552000
#
#       NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# ...

# %%
sns.boxplot(data_no_outlier.Temp)

# %%
sns.boxplot(data_no_outlier['D.O. (mg/l)'])

# %%
# Most of the outlier got filtered using the IQR score method but need more cleaning for accurate predictions
data_no_outlier
# Out:
#            Temp  D.O. (mg/l)    PH  CONDUCTIVITY (µmhos/cm)  B.O.D. (mg/l)  \
# 0     30.600000          6.7  7.50                    203.0       6.940049
# 2     29.500000          6.3  6.90                    179.0       1.700000
# 4     29.500000          5.8  7.30                     83.0       1.900000
# 5     30.000000          5.5  7.40                     81.0       1.500000
# 6     29.200000          6.1  6.70                    308.0       1.400000
# ...         ...          ...   ...                      ...            ...
# 1896  26.209814          6.6  7.81                    603.2       2.675000
# 1897  28.000000          6.6  7.49                    571.5       2.091000
# 1898  28.000000          5.4  7.16                     75.8       2.092000
# 1899  30.000000          5.4  7.37                    104.8       1.802000
# 1900  29.000000          5.3  7.37                    102.2       2.552000
#
#       NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# ...

# %% [markdown]
# # Renaming columns in the Dataframe

# %%
TEMP = data_no_outlier.iloc[0:,0]
DO= data_no_outlier.iloc[0:,1]
PH = data_no_outlier.iloc[0:,2]  
CO = data_no_outlier.iloc[0:,3]
YEAR=data_no_outlier.iloc[0:,8]
TC=data_no_outlier.iloc[0:,7]
BOD = data_no_outlier.iloc[0:,4]
NA= data_no_outlier.iloc[0:,5]

# %%
data=pd.concat([TEMP,DO,PH,CO,BOD,NA,TC,YEAR],axis=1)
data.columns = ['TEMP','DO','PH','CO','BOD','NA','TC','YEAR']

# %%
data
# Out:
#            TEMP   DO    PH     CO       BOD        NA      TC  YEAR
# 0     30.600000  6.7  7.50  203.0  6.940049  0.100000    27.0  2014
# 2     29.500000  6.3  6.90  179.0  1.700000  0.100000  5330.0  2014
# 4     29.500000  5.8  7.30   83.0  1.900000  0.400000  5500.0  2014
# 5     30.000000  5.5  7.40   81.0  1.500000  0.100000  4049.0  2014
# 6     29.200000  6.1  6.70  308.0  1.400000  0.300000  5672.0  2014
# ...         ...  ...   ...    ...       ...       ...     ...   ...
# 1896  26.209814  6.6  7.81  603.2  2.675000  0.263000   191.0  2005
# 1897  28.000000  6.6  7.49  571.5  2.091000  0.256000   273.0  2005
# 1898  28.000000  5.4  7.16   75.8  2.092000  1.623079   513.0  2005
# 1899  30.000000  5.4  7.37  104.8  1.802000  0.215000   557.0  2005
# 1900  29.000000  5.3  7.37  102.2  2.552000  0.202000   583.0  2005
#
# [1106 rows x 8 columns]

# %% [markdown]
# # Feature Scaling

# %%
data['newpH']=data.PH.apply(lambda x: (100 if (8.5>=x>=7)  
                                 else(80 if  (8.6>=x>=8.5) or (6.9>=x>=6.8) 
                                      else(60 if (8.8>=x>=8.6) or (6.8>=x>=6.7) 
                                          else(40 if (9>=x>=8.8) or (6.7>=x>=6.5)
                                              else 0)))))

# %%
data['newDO']=data.DO.apply(lambda x:(100 if (x>=6)  
                                 else(80 if  (6>=x>=5.1) 
                                      else(60 if (5>=x>=4.1)
                                          else(40 if (4>=x>=3) 
                                              else 0)))))

# %%
data['newTC']=data.TC.apply(lambda x:(100 if (5>=x>=0)  
                                 else(80 if  (50>=x>=5) 
                                      else(60 if (500>=x>=50)
                                          else(40 if (10000>=x>=500) 
                                              else 0)))))

# %%
data['newBDO']=data.BOD.apply(lambda x:(100 if (3>=x>=0)  
                                 else(80 if  (6>=x>=3) 
                                      else(60 if (80>=x>=6)
                                          else(40 if (125>=x>=80) 
                                              else 0)))))

# %%
data['newCO']=data.CO.apply(lambda x:(100 if (75>=x>=0)  
                                 else(80 if  (150>=x>=75) 
                                      else(60 if (225>=x>=150)
                                          else(40 if (300>=x>=225) 
                                              else 0)))))

# %%
data['newNA']=data.NA.apply(lambda x:(100 if (20>=x>=0)  
                                 else(80 if  (50>=x>=20) 
                                      else(60 if (100>=x>=50)
                                          else(40 if (200>=x>=100) 
                                              else 0)))))

# %%
data['PH']=data.newpH * 0.165
data['DO']=data.newDO * 0.281
data['BOD']=data.newBDO * 0.234
data['CO']=data.newCO* 0.009
data['NA']=data.newNA * 0.028
data['TC']=data.newTC * 0.281
data['WQI']=data.PH+data.DO+data.BOD+data.CO+data.NA+data.TC 
data
# Out:
#            TEMP     DO    PH    CO    BOD   NA     TC  YEAR  newpH  newDO  \
# 0     30.600000  28.10  16.5  0.54  14.04  2.8  22.48  2014    100    100
# 2     29.500000  28.10  13.2  0.54  23.40  2.8  11.24  2014     80    100
# 4     29.500000  22.48  16.5  0.72  23.40  2.8  11.24  2014    100     80
# 5     30.000000  22.48  16.5  0.72  23.40  2.8  11.24  2014    100     80
# 6     29.200000  28.10   9.9  0.00  23.40  2.8  11.24  2014     60    100
# ...         ...    ...   ...   ...    ...  ...    ...   ...    ...    ...
# 1896  26.209814  28.10  16.5  0.00  23.40  2.8  16.86  2005    100    100
# 1897  28.000000  28.10  16.5  0.00  23.40  2.8  16.86  2005    100    100
# 1898  28.000000  22.48  16.5  0.72  23.40  2.8  11.24  2005    100     80
# 1899  30.000000  22.48  16.5  0.72  23.40  2.8  11.24  2005    100     80
# 1900  29.000000  22.48  16.5  0.72  23.40  2.8  11.24  2005    100     80
#
#       newTC  newBDO  newCO  newNA    WQI
# ...

# %% [markdown]
# # Data Visualization

# %%
plt.plot(data['YEAR'],data['WQI'])

# %%
plt.scatter(data['YEAR'],data['WQI'])

# %%
plt.scatter(data['YEAR'],data['TEMP'])

# %%
plt.scatter(data['TEMP'],data['WQI'])

# %%
plt.scatter(data['BOD'],data['WQI'])

# %%
plt.scatter(data['CO'],data['WQI'])

# %%
plt.scatter(data['NA'],data['WQI'])

# %%
plt.scatter(data['DO'],data['WQI'])

# %% [markdown]
# # Model Building

# %%
x = data.iloc[:,0:8].values

# %%
y = data.iloc[:,14].values

# %%
x
# Out:
# array([[  30.6 ,   28.1 ,   16.5 , ...,    2.8 ,   22.48, 2014.  ],
#        [  29.5 ,   28.1 ,   13.2 , ...,    2.8 ,   11.24, 2014.  ],
#        [  29.5 ,   22.48,   16.5 , ...,    2.8 ,   11.24, 2014.  ],
#        ...,
#        [  28.  ,   22.48,   16.5 , ...,    2.8 ,   11.24, 2005.  ],
#        [  30.  ,   22.48,   16.5 , ...,    2.8 ,   11.24, 2005.  ],
#        [  29.  ,   22.48,   16.5 , ...,    2.8 ,   11.24, 2005.  ]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
mr = LinearRegression()
mr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = mr.predict(x_test)
y_pred
# Out:
# array([82.76, 79.46, 83.7 , 94.  , 83.7 , 87.66, 88.38, 66.44, 73.04,
#        93.28, 75.8 , 78.66, 79.46, 82.94, 79.46, 82.94, 90.34, 83.7 ,
#        82.98, 88.56, 76.78, 87.66, 77.14, 71.88, 77.36, 88.02, 79.64,
#        77.72, 93.28, 87.66, 82.94, 82.94, 82.76, 94.  , 93.82, 77.32,
#        88.02, 88.2 , 71.74, 76.42, 78.08, 78.48, 88.38, 83.7 , 72.86,
#        87.66, 79.46, 88.38, 88.38, 82.94, 88.38, 93.28, 88.56, 88.38,
#        81.78, 94.76, 88.56, 94.18, 88.02, 88.38, 82.94, 99.62, 82.58,
#        71.7 , 83.7 , 88.56, 82.94, 87.66, 79.64, 93.82, 82.94, 88.38,
#        89.32, 79.64, 79.46, 73.04, 94.  , 82.58, 82.4 , 93.28, 82.98,
#        82.94, 78.12, 88.38, 66.44, 77.9 , 79.64, 87.66, 74.02, 82.58,
#        88.56, 83.7 , 82.98, 77.5 , 89.32, 79.28, 88.38, 82.04, 78.3 ,
#        77.14, 73.04, 88.2 , 77.32, 76.34, 88.56, 87.66, 82.94, 93.64,
#        88.02, 73.04, 78.74, 82.58, 83.7 , 87.66, 78.66, 75.98, 85.08,
# ...

# %%
y_test
# Out:
# array([82.76, 79.46, 83.7 , 94.  , 83.7 , 87.66, 88.38, 66.44, 73.04,
#        93.28, 75.8 , 78.66, 79.46, 82.94, 79.46, 82.94, 90.34, 83.7 ,
#        82.98, 88.56, 76.78, 87.66, 77.14, 71.88, 77.36, 88.02, 79.64,
#        77.72, 93.28, 87.66, 82.94, 82.94, 82.76, 94.  , 93.82, 77.32,
#        88.02, 88.2 , 71.74, 76.42, 78.08, 78.48, 88.38, 83.7 , 72.86,
#        87.66, 79.46, 88.38, 88.38, 82.94, 88.38, 93.28, 88.56, 88.38,
#        81.78, 94.76, 88.56, 94.18, 88.02, 88.38, 82.94, 99.62, 82.58,
#        71.7 , 83.7 , 88.56, 82.94, 87.66, 79.64, 93.82, 82.94, 88.38,
#        89.32, 79.64, 79.46, 73.04, 94.  , 82.58, 82.4 , 93.28, 82.98,
#        82.94, 78.12, 88.38, 66.44, 77.9 , 79.64, 87.66, 74.02, 82.58,
#        88.56, 83.7 , 82.98, 77.5 , 89.32, 79.28, 88.38, 82.04, 78.3 ,
#        77.14, 73.04, 88.2 , 77.32, 76.34, 88.56, 87.66, 82.94, 93.64,
#        88.02, 73.04, 78.74, 82.58, 83.7 , 87.66, 78.66, 75.98, 85.08,
# ...

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 1.0

# %%
import pickle
pickle.dump(mr,open('model_new.pkl','wb'))
